# %% [markdown]
# # Compare available SDDbs
#
# An informal notebook for quick comparisons of different copies of SDDb available.
#
# See the [GitHub Issue](https://github.com/krank-sources/sddb/issues/1) for a full table of versions and their details.

# %%
import itertools

import pandas as pd
import pooch

from IPython.display import display

# %%
CACHE_DIR = pooch.os_cache("pooch").joinpath("sddb")
REGISTRY = {
    "github_v1-alpha.1": {
        "url": "https://github.com/krank-sources/sddb/raw/refs/tags/v1-alpha.1/raw/dream-export.csv.xz",
        "known_hash": "md5:7a28c8f29584ab3375db2dc2bbc86d6d",
    },
    "github_v1-alpha.2": {
        "url": "https://github.com/krank-sources/sddb/raw/refs/tags/v1-alpha.1/raw/dream-export.csv.xz",
        "known_hash": "md5:7a28c8f29584ab3375db2dc2bbc86d6d",
    },
    "github_v1-alpha.1_processed": {
        "url": "https://github.com/krank-sources/sddb/releases/download/v1-alpha.1/sddb.tsv.xz",
        "known_hash": "md5:f05c3615c978a16dcf0ddb2440c56914",
    },
    "github_v1-alpha.2_processed": {
        "url": "https://github.com/krank-sources/sddb/releases/download/v1-alpha.2/sddb.tsv.xz",
        "known_hash": "md5:082496b09f8973e511e15190bc344ac1",
    },
    "zenodo_v1": {
        "url": "https://zenodo.org/records/11662064/files/dream-export.csv?download=1",
        "known_hash": "md5:2252f45157859f2d598023fc84ad436c",
    },
    "zenodo_v2": {
        "url": "https://zenodo.org/records/18076716/files/dream_search_2025-12-28T15_50_30.592Z.csv?download=1",
        "known_hash": "md5:4ecfb8cd2a83eabe75d2b6537ca846b6",
    },
}

# %% [markdown]
# ## Load different copies

# %%
# Download and cache files as needed
filenames = {
    version: pooch.retrieve(path=CACHE_DIR, **params) for version, params in REGISTRY.items()
}

# %%
# Read in all dataframes
dataframes = {
    version: pd.read_csv(fname, sep="\t" if "processed" in version else ",", low_memory=False)
    for version, fname in filenames.items()
}

# %%
assert dataframes["github_v1-alpha.1"].equals(dataframes["github_v1-alpha.2"])
del dataframes["github_v1-alpha.2"]

assert (
    dataframes["github_v1-alpha.2_processed"]
    .equals(
        dataframes["github_v1-alpha.1_processed"]
        .sort_values(["dataset", "author", "dream"])
        .reset_index(drop=True)
    )
)
del dataframes["github_v1-alpha.1_processed"]

# Make sure none of remaining are identical
for x, y in itertools.combinations(dataframes.values(), 2):
    assert not x.equals(y), "DataFrames should not be identical"

# %%
dataframes["zenodo_v2"].columns[:10]
# Out:
# Index(['Dream Report ID', 'Title', 'Dream Text', 'Participant ID', 'Gender',
#        'Age', 'Word Count', 'Dream Date', 'Survey Name', 'Survey ID'],
#       dtype='object')

# %%
# Make a dataframe with sizes of each dataframe

DATASET_COLS = {
    "github_v1-alpha.1": "survey",
    "github_v1-alpha.2_processed": "dataset",
    "zenodo_v1": "survey",
    "zenodo_v2": "Survey Name",
}
REPORT_COLS = {
    "github_v1-alpha.1": "answer_text",
    "github_v1-alpha.2_processed": "dream",
    "zenodo_v1": "answer_text",
    "zenodo_v2": "Dream Text",
}

info = pd.DataFrame.from_dict(
    {
        version: {
            "n_rows": len(df),
            "n_columns": len(df.columns),
            "n_empty_cols": df.isna().all().sum(),
            "n_datasets": df[DATASET_COLS[version]].nunique(),
            "n_nan_datasets": df[DATASET_COLS[version]].isna().sum(),
            "n_nan_reports": df[REPORT_COLS[version]].isna().sum(),
            "n_blank_reports": df[REPORT_COLS[version]].eq("").sum(),
            "avg_wc": df[REPORT_COLS[version]].str.split().str.len().mean().round(3),
            "min_wc": df[REPORT_COLS[version]].str.split().str.len().min(),
            "max_wc": df[REPORT_COLS[version]].str.split().str.len().max(),
        }
        for version, df in dataframes.items()
    },
    orient="index",
)

display(info)
# Out:
#                              n_rows  n_columns  n_empty_cols  n_datasets  \
# github_v1-alpha.1             39089        276             0          83
# github_v1-alpha.2_processed   28570          3             0          60
# zenodo_v1                     39089        184             0          83
# zenodo_v2                     44556         12             4          85
#
#                              n_nan_datasets  n_nan_reports  n_blank_reports  \
# github_v1-alpha.1                         0           1567                0
# github_v1-alpha.2_processed               0              0                0
# zenodo_v1                                 0           1567                0
# zenodo_v2                                 0           1567                0
#
#                               avg_wc  min_wc  max_wc
# github_v1-alpha.1             89.493     1.0  2681.0
# github_v1-alpha.2_processed  104.816     1.0   982.0
# zenodo_v1                     89.493     1.0  2681.0
# zenodo_v2                    104.363     1.0  2681.0

# %%
# Identify which columns were removed across source versions
gh = dataframes["github_v1-alpha.1"]
z1 = dataframes["zenodo_v1"]
z2 = dataframes["zenodo_v2"]

most_columns = max(len(gh.columns), len(z1.columns), len(z2.columns))
print(f"{'github_v1-alpha.1':>40} {'zenodo_v1':>30} {'zenodo_v2':>20}")
for i in range(most_columns):
    c1 = gh.columns[i] if i < len(gh.columns) else "<no column>"
    c2 = z1.columns[i] if i < len(z1.columns) else "<no column>"
    c3 = z2.columns[i] if i < len(z2.columns) else "<no column>"
    print(f"{c1:>40} {c2:>30} {c3:>20}")
# Out:
#                        github_v1-alpha.1                      zenodo_v1            zenodo_v2
#                              answer_text                    answer_text      Dream Report ID
#                               word_count                     word_count                Title
#                        dream_entry_title              dream_entry_title           Dream Text
#                                     date                           date       Participant ID
#                               respondent                     respondent               Gender
#                                   survey                         survey                  Age
#                  Religious Affiliation B              Familiar Settings           Word Count
#                        Familiar Settings      Non-Physical Aggression 3           Dream Date
#                Non-Physical Aggression 3      Non-Physical Aggression 4          Survey Name
#                Non-Physical Aggression 4      Non-Physical Aggression 5            Survey ID
#                Non-Physical Aggression 5                 Friendliness 3             Question
#                           Friendliness 3                 Friendliness 4           Categories
#                           Friendliness 4                 Friendliness 5          <no column>
#                           Friendliness 5          Physical Aggression 2          <no column>
#                    Physical Aggression 2          Physical Aggression 4          <no column>
#                    Physical Aggression 4                    Sexuality 5          <no column>
#                              Sexuality 5               Outside Settings          <no column>
#                         Outside Settings      Non-Physical Aggression 1          <no column>
#                Non-Physical Aggression 1                Inside Settings          <no column>
#                          Inside Settings      Non-Physical Aggression 2          <no column>
#                Non-Physical Aggression 2                 Friendliness 1          <no column>
#                           Friendliness 1                 Friendliness 2          <no column>
#                           Friendliness 2          Physical Aggression 1          <no column>
#                    Physical Aggression 1          Physical Aggression 3          <no column>
#                    Physical Aggression 3          Physical Aggression 5          <no column>
#                    Physical Aggression 5                    Sexuality 1          <no column>
#                              Sexuality 1                    Sexuality 2          <no column>
#                              Sexuality 2                    Sexuality 3          <no column>
#                              Sexuality 3                    Sexuality 4          <no column>
#                              Sexuality 4                        Animals          <no column>
#                                  Animals                       Children          <no column>
#                                 Children                      Creatures          <no column>
#                                Creatures                Dead Characters          <no column>
#                          Dead Characters              Family Characters          <no column>
#                        Family Characters              Female Characters          <no column>
#                        Female Characters                        Friends          <no column>
#                                  Friends           Imaginary Characters          <no column>
#                     Imaginary Characters                Male Characters          <no column>
#                          Male Characters                  Metamorphosis          <no column>
#                            Metamorphosis        Occupational Characters          <no column>
#                  Occupational Characters           Prominent Characters          <no column>
#                     Prominent Characters       Racial/Ethnic Characters          <no column>
#                 Racial/Ethnic Characters                      Strangers          <no column>
#                                Strangers               Total Characters          <no column>
#                         Total Characters                 Dream Location          <no column>
#                           Dream Location                          Anger          <no column>
#                                    Anger                           Fear          <no column>
#                                     Fear                      Happiness          <no column>
#                                Happiness                        Sadness          <no column>
#                                  Sadness                         Wonder          <no column>
#                                   Wonder                  Good Fortunes          <no column>
#                            Good Fortunes                     Misfortune          <no column>
#                               Misfortune           Waking Report: SCU 1          <no column>
#                     Waking Report: SCU 1  last_nights_dream_day_of_week          <no column>
#            last_nights_dream_day_of_week     last_nights_dream_location          <no column>
#               last_nights_dream_location        last_nights_dream_title          <no column>
#                  last_nights_dream_title last_nights_dream_significance          <no column>
#           last_nights_dream_significance              Social Media Used          <no column>
#                                Education                 Race/Ethnicity          <no column>
#                     Dream Recall Changes      Sports Played or Interest          <no column>
#                    Pandemic Dream Report                      Age Range          <no column>
#                        social_nets_mem_7        Current Grade in School          <no column>
#                                      age                            Age          <no column>
#                                   gender                       ZIP Code          <no column>
#                                   region         Pandemic Mental Health          <no column>
#                                     race                Pandemic Social          <no column>
#                                     educ              Pandemic Finances          <no column>
#                 profile_marstat_2018_r_1            Dream Tone Pandemic          <no column>
#                 profile_marstat_2018_r_2                    Income Tier          <no column>
#                 profile_marstat_2018_r_3                Income (values)          <no column>
#                 profile_marstat_2018_r_4           Dream Recall Changes          <no column>
#                 profile_marstat_2018_r_5          Sex Assigned at Birth          <no column>
#                 profile_marstat_2018_r_6        Religious Affiliation B          <no column>
#                 profile_marstat_2018_r_7                School Location          <no column>
#                 profile_marstat_2018_r_8                    School Type          <no column>
#                 profile_marstat_2018_r_9                   Prop Weights          <no column>
#                profile_marstat_2018_r_10 13-17 years old: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.          <no column>
#                profile_marstat_2018_r_11 2 years old or younger: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.          <no column>
#                             parentyn_r_1 3-5 years old: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.          <no column>
#                             parentyn_r_2 6-9 years old: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.          <no column>
#                             parentyn_r_3 Would you be interested in speaking with a reporter about the results of this survey?          <no column>
#                             parentyn_r_4        Typical Dreams: Falling          <no column>
#                             parentyn_r_5                          DATE1          <no column>
#                profile_gross_household_r                          DATE2          <no column>
#                        social_nets_mem_1                     Generation          <no column>
#                        social_nets_mem_2 Earliest Remembered Dream: Recurrent          <no column>
#                        social_nets_mem_3                 2008 President          <no column>
#                        social_nets_mem_4       Hours of sleep per night          <no column>
#                        social_nets_mem_5 Sexual Dreams Before Waking Sexual Activity          <no column>
#                        social_nets_mem_6         Typical Dreams: Sexual          <no column>
#                        social_nets_mem_8  More Spiritual Than Religious          <no column>
#                       social_nets_mem_10        Parent of a young child          <no column>
#                       social_nets_mem_12 Would you be interested in participating in an interactive online focus group in the future?          <no column>
#                       social_nets_mem_13 Typical Dreams: Just Like Waking Life          <no column>
#                       social_nets_mem_15      Typical Dreams: Awareness          <no column>
#                       social_nets_mem_16        Typical Dreams: Control          <no column>
#                       social_nets_mem_17   Most Recent Dream: Recurrent          <no column>
#                       social_nets_mem_19     Worst Nightmare: Recurrent          <no column>
#                       social_nets_mem_20                     Registered          <no column>
#                       social_nets_mem_21                     Likelihood          <no column>
#                       social_nets_mem_98         2008 Presidential Vote          <no column>
#                       social_nets_mem_99                Political Party          <no column>
#                                age_cross       Pandemic Physical Health          <no column>
#                                  educ_w8           Talking About Dreams          <no column>
#                              race_xbreak     Typical Dreams: Visitation          <no column>
#                                   weight         Typical Dreams: Flying          <no column>
#                                   LSD_q1 Typical Dreams: Being Chased or Attacked          <no column>
#              interests_sports_playing_31               Race/Ethnicity D          <no column>
#              interests_sports_playing_32     Insomnia Nights Per Week A          <no column>
#              interests_sports_playing_33        Religious Affiliation A          <no column>
#              interests_sports_playing_12           Born Again Christian          <no column>
#              interests_sports_playing_34        Coffee drinkers at home          <no column>
#              interests_sports_playing_35                   Dream Recall          <no column>
#              interests_sports_playing_36                   2008 results          <no column>
#              interests_sports_playing_37               Nightmare Recall          <no column>
#              interests_sports_playing_38                          Party          <no column>
#              interests_sports_playing_39                 College Degree          <no column>
#              interests_sports_playing_40                    Race Recode          <no column>
#              interests_sports_playing_41             Political Ideology          <no column>
#              interests_sports_playing_42               Ideology Recoded          <no column>
#              interests_sports_playing_43           Political Ideology 2          <no column>
#              interests_sports_playing_44                 Marital status          <no column>
#               interests_sports_playing_7               Marital Status A          <no column>
#              interests_sports_playing_45 <BR>Do you or anyone in your household brew any of the coffee consumed at home on a Keurig single brew (k-cup) machine?          <no column>
#              interests_sports_playing_17            Religious Worship A          <no column>
#              interests_sports_playing_46                Tea Party Views          <no column>
#              interests_sports_playing_47             Passport Ownership          <no column>
#               interests_sports_playing_4          US State of Residence          <no column>
#              interests_sports_playing_48 Employed full time: Q2149 What is your employment status? Please select all that apply.          <no column>
#              interests_sports_playing_49                             ID          <no column>
#              interests_sports_playing_50 Political Party x Race/Ethnicity          <no column>
#              interests_sports_playing_23        Marital Status & Gender          <no column>
#               interests_sports_playing_6                           TIME          <no column>
#              interests_sports_playing_51                          Total          <no column>
#              interests_sports_playing_52                         <none>          <no column>
#              interests_sports_playing_67          Pandemic Dream Report          <no column>
#              interests_sports_playing_54                Education Level          <no column>
#              interests_sports_playing_55       Education Level (values)          <no column>
#               interests_sports_playing_3                         Region          <no column>
#              interests_sports_playing_56       profile_marstat_2018_r_1          <no column>
#              interests_sports_playing_57       profile_marstat_2018_r_2          <no column>
#              interests_sports_playing_58       profile_marstat_2018_r_3          <no column>
#              interests_sports_playing_59       profile_marstat_2018_r_4          <no column>
#              interests_sports_playing_22       profile_marstat_2018_r_5          <no column>
#              interests_sports_playing_60       profile_marstat_2018_r_6          <no column>
#              interests_sports_playing_61       profile_marstat_2018_r_7          <no column>
#              interests_sports_playing_28       profile_marstat_2018_r_8          <no column>
#               interests_sports_playing_1       profile_marstat_2018_r_9          <no column>
#               interests_sports_playing_2      profile_marstat_2018_r_10          <no column>
#              interests_sports_playing_62      profile_marstat_2018_r_11          <no column>
#              interests_sports_playing_21                   parentyn_r_1          <no column>
#              interests_sports_playing_66                   parentyn_r_2          <no column>
#              interests_sports_playing_16                   parentyn_r_3          <no column>
#              interests_sports_playing_63                   parentyn_r_4          <no column>
#              interests_sports_playing_64                   parentyn_r_5          <no column>
#              interests_sports_playing_65                         weight          <no column>
#              interests_sports_playing_99                         LSD_q1          <no column>
#                                   DSD_q1                         DSD_q1          <no column>
#                                   DSD_q2                         DSD_q2          <no column>
#                                   LSD_q3                         LSD_q3          <no column>
#              interests_sports_playing_cb        Race/Ethnicity (values)          <no column>
#                                      Age            Mobile Device Usage          <no column>
#                                     Race 10-12 years old: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.          <no column>
# Typical Dreams: Being Chased or Attacked I am not the parent/legal guardian of any child under 18 years old who is living at home with me.: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.          <no column>
#                              Age Group A In what country or region do you currently reside?          <no column>
#                         Race/Ethnicity D What type of Internet connection do you have for your home computer or other primary computer?          <no column>
#                                   Gender Excluding email, how many hours a week do you spend on the Internet or World Wide Web?          <no column>
#                         Race/Ethnicity C               Marital Status B          <no column>
#                  Current Grade in School Including you, how many adults (age 18 or over) live in this household?          <no column>
#                          School Location How many children under the age of 18 live in this household?          <no column>
#                              School Type Which of the following best describes your current primary residence? I/We live in...          <no column>
#                             Prop Weights Employed part time: Q2149 What is your employment status? Please select all that apply.          <no column>
#                              Age Group B Self-employed: Q2149 What is your employment status? Please select all that apply.          <no column>
# Would you be interested in speaking with a reporter about the results of this survey? Not employed, but looking for work: Q2149 What is your employment status? Please select all that apply.          <no column>
#                  Typical Dreams: Falling Not employed and not looking for work: Q2149 What is your employment status? Please select all that apply.          <no column>
#                                    DATE1 Retired: Q2149 What is your employment status? Please select all that apply.          <no column>
#                                    DATE2 Not employed, unable to work due to a disability or illness: Q2149 What is your employment status? Please select all that apply.          <no column>
#                               Generation Student: Q2149 What is your employment status? Please select all that apply.          <no column>
#     Earliest Remembered Dream: Recurrent Homemaker: Q2149 What is your employment status? Please select all that apply.          <no column>
#                           2008 President               Race/Ethnicity E          <no column>
#                              US Region A                   Unnamed: 180          <no column>
#                 Hours of sleep per night     Insomnia Nights Per Week B          <no column>
# Sexual Dreams Before Waking Sexual Activity           Country of Residence          <no column>
#                   Typical Dreams: Sexual  2020 President Trump approval          <no column>
#            More Spiritual Than Religious                    <no column>          <no column>
#                  Parent of a young child                    <no column>          <no column>
# Would you be interested in participating in an interactive online focus group in the future?                    <no column>          <no column>
#    Typical Dreams: Just Like Waking Life                    <no column>          <no column>
#                Typical Dreams: Awareness                    <no column>          <no column>
#                  Typical Dreams: Control                    <no column>          <no column>
#             Most Recent Dream: Recurrent                    <no column>          <no column>
#               Worst Nightmare: Recurrent                    <no column>          <no column>
#                               Registered                    <no column>          <no column>
#                               Likelihood                    <no column>          <no column>
#                   2008 Presidential Vote                    <no column>          <no column>
#                          Political Party                    <no column>          <no column>
#                     Talking About Dreams                    <no column>          <no column>
#               Typical Dreams: Visitation                    <no column>          <no column>
#                   Typical Dreams: Flying                    <no column>          <no column>
#               Insomnia Nights Per Week A                    <no column>          <no column>
#                  Religious Affiliation A                    <no column>          <no column>
#                     Born Again Christian                    <no column>          <no column>
#                  Coffee drinkers at home                    <no column>          <no column>
#                              Education A                    <no column>          <no column>
#                              Race Recode                    <no column>          <no column>
#                         Race/Ethnicity A                    <no column>          <no column>
#                       Political Ideology                    <no column>          <no column>
#                         Ideology Recoded                    <no column>          <no column>
#                     Political Ideology 2                    <no column>          <no column>
#                           Marital status                    <no column>          <no column>
#                         Marital Status A                    <no column>          <no column>
#                      Personal Finances A                    <no column>          <no column>
# <BR>Do you or anyone in your household brew any of the coffee consumed at home on a Keurig single brew (k-cup) machine?                    <no column>          <no column>
#                      Religious Worship A                    <no column>          <no column>
#                          Tea Party Views                    <no column>          <no column>
#                   What is your zip code?                    <no column>          <no column>
#                       Passport Ownership                    <no column>          <no column>
#                    US State of Residence                    <no column>          <no column>
# 13-17 years old: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.                    <no column>          <no column>
#                         Marital Status B                    <no column>          <no column>
# Retired: Q2149 What is your employment status? Please select all that apply.                    <no column>          <no column>
# Student: Q2149 What is your employment status? Please select all that apply.                    <no column>          <no column>
#                      Personal Finances B                    <no column>          <no column>
#                                       ID                    <no column>          <no column>
#         Political Party x Race/Ethnicity                    <no column>          <no column>
#                  Marital Status & Gender                    <no column>          <no column>
#                                     TIME                    <no column>          <no column>
#                                    Total                    <no column>          <no column>
#                                   <none>                    <no column>          <no column>
#                         Race/Ethnicity F                    <no column>          <no column>
#                      Dream Tone Pandemic                    <no column>          <no column>
#                 Pandemic Physical Health                    <no column>          <no column>
#                          Pandemic Social                    <no column>          <no column>
#                        Pandemic Finances                    <no column>          <no column>
#                   Pandemic Mental Health                    <no column>          <no column>
#                             Dream Recall                    <no column>          <no column>
#                             2008 results                    <no column>          <no column>
#                         Nightmare Recall                    <no column>          <no column>
#                                    Party                    <no column>          <no column>
#                              Education D                    <no column>          <no column>
#                              US Region F                    <no column>          <no column>
# 10-12 years old: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.                    <no column>          <no column>
# 2 years old or younger: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.                    <no column>          <no column>
# 3-5 years old: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.                    <no column>          <no column>
# 6-9 years old: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.                    <no column>          <no column>
# I am not the parent/legal guardian of any child under 18 years old who is living at home with me.: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.                    <no column>          <no column>
# In what country or region do you currently reside?                    <no column>          <no column>
# What type of Internet connection do you have for your home computer or other primary computer?                    <no column>          <no column>
# Excluding email, how many hours a week do you spend on the Internet or World Wide Web?                    <no column>          <no column>
# Including you, how many adults (age 18 or over) live in this household?                    <no column>          <no column>
# How many children under the age of 18 live in this household?                    <no column>          <no column>
# Which of the following best describes your current primary residence? I/We live in...                    <no column>          <no column>
#                              Education B                    <no column>          <no column>
# Employed full time: Q2149 What is your employment status? Please select all that apply.                    <no column>          <no column>
# Employed part time: Q2149 What is your employment status? Please select all that apply.                    <no column>          <no column>
# Self-employed: Q2149 What is your employment status? Please select all that apply.                    <no column>          <no column>
# Not employed, but looking for work: Q2149 What is your employment status? Please select all that apply.                    <no column>          <no column>
# Not employed and not looking for work: Q2149 What is your employment status? Please select all that apply.                    <no column>          <no column>
# Not employed, unable to work due to a disability or illness: Q2149 What is your employment status? Please select all that apply.                    <no column>          <no column>
# Homemaker: Q2149 What is your employment status? Please select all that apply.                    <no column>          <no column>
#                      Personal Finances C                    <no column>          <no column>
#                              US Region B                    <no column>          <no column>
#                         Race/Ethnicity E                    <no column>          <no column>
#                         Race/Ethnicity B                    <no column>          <no column>
#                             Unnamed: 264                    <no column>          <no column>
#               Insomnia Nights Per Week B                    <no column>          <no column>
#                     Country of Residence                    <no column>          <no column>
#                                 ZIP Code                    <no column>          <no column>
#               Mobile devices: smartphone                    <no column>          <no column>
#    Mobile devices: standard mobile phone                    <no column>          <no column>
#                   Mobile devices: tablet                    <no column>          <no column>
#                  Mobile devices: eReader                    <no column>          <no column>
#     Mobile devices: other mobile devices                    <no column>          <no column>
#                     Mobile devices: none                    <no column>          <no column>
#                      Personal Finances E                    <no column>          <no column>
#            2020 President Trump approval                    <no column>          <no column>

# %%
for version, df in dataframes.items():
    print("=" * 40)
    print()
    print(f"{version} columns:")
    for col in df:
        print("\t- " + col)
    print()
# Out:
# ========================================
#
# github_v1-alpha.1 columns:
# 	- answer_text
# 	- word_count
# 	- dream_entry_title
# 	- date
# 	- respondent
# 	- survey
# 	- Religious Affiliation B
# 	- Familiar Settings
# 	- Non-Physical Aggression 3
# 	- Non-Physical Aggression 4
# 	- Non-Physical Aggression 5
# 	- Friendliness 3
# 	- Friendliness 4
# 	- Friendliness 5
# 	- Physical Aggression 2
# 	- Physical Aggression 4
# 	- Sexuality 5
# 	- Outside Settings
# 	- Non-Physical Aggression 1
# 	- Inside Settings
# 	- Non-Physical Aggression 2
# 	- Friendliness 1
# 	- Friendliness 2
# 	- Physical Aggression 1
# 	- Physical Aggression 3
# 	- Physical Aggression 5
# 	- Sexuality 1
# 	- Sexuality 2
# 	- Sexuality 3
# 	- Sexuality 4
# 	- Animals
# 	- Children
# 	- Creatures
# 	- Dead Characters
# 	- Family Characters
# 	- Female Characters
# 	- Friends
# 	- Imaginary Characters
# 	- Male Characters
# 	- Metamorphosis
# 	- Occupational Characters
# 	- Prominent Characters
# 	- Racial/Ethnic Characters
# 	- Strangers
# 	- Total Characters
# 	- Dream Location
# 	- Anger
# 	- Fear
# 	- Happiness
# 	- Sadness
# 	- Wonder
# 	- Good Fortunes
# 	- Misfortune
# 	- Waking Report: SCU 1
# 	- last_nights_dream_day_of_week
# 	- last_nights_dream_location
# 	- last_nights_dream_title
# 	- last_nights_dream_significance
# 	- Typical Dreams: Visitation
# 	- Typical Dreams: Flying
# 	- Typical Dreams: Being Chased or Attacked
# 	- Race/Ethnicity D
# 	- Insomnia Nights Per Week A
# 	- Religious Affiliation A
# 	- Born Again Christian
# 	- Coffee drinkers at home
# 	- Dream Recall
# 	- 2008 results
# 	- Nightmare Recall
# 	- Party
# 	- College Degree
# 	- Race Recode
# 	- Political Ideology
# 	- Ideology Recoded
# 	- Political Ideology 2
# 	- Marital status
# 	- Marital Status A
# 	- <BR>Do you or anyone in your household brew any of the coffee consumed at home on a Keurig single brew (k-cup) machine?
# 	- Religious Worship A
# 	- Tea Party Views
# 	- Passport Ownership
# 	- US State of Residence
# 	- Employed full time: Q2149 What is your employment status? Please select all that apply.
# 	- ID
# 	- Political Party x Race/Ethnicity
# 	- Marital Status & Gender
# 	- TIME
# 	- Total
# 	- <none>
# 	- Pandemic Dream Report
# 	- Education Level
# 	- Education Level (values)
# 	- Region
# 	- profile_marstat_2018_r_1
# 	- profile_marstat_2018_r_2
# 	- profile_marstat_2018_r_3
# 	- profile_marstat_2018_r_4
# 	- profile_marstat_2018_r_5
# 	- profile_marstat_2018_r_6
# 	- profile_marstat_2018_r_7
# 	- profile_marstat_2018_r_8
# 	- profile_marstat_2018_r_9
# 	- profile_marstat_2018_r_10
# 	- profile_marstat_2018_r_11
# 	- parentyn_r_1
# 	- parentyn_r_2
# 	- parentyn_r_3
# 	- parentyn_r_4
# 	- parentyn_r_5
# 	- weight
# 	- LSD_q1
# 	- DSD_q1
# 	- DSD_q2
# 	- LSD_q3
# 	- Race/Ethnicity (values)
# 	- Mobile Device Usage
# 	- 10-12 years old: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.
# 	- I am not the parent/legal guardian of any child under 18 years old who is living at home with me.: Q2102 Are you the parent/legal guardian of any child/children living at home with you who is/are...? Please select all that apply.
# 	- In what country or region do you currently reside?
# 	- What type of Internet connection do you have for your home computer or other primary computer?
# 	- Excluding email, how many hours a week do you spend on the Internet or World Wide Web?
# 	- Marital Status B
# 	- Including you, how many adults (age 18 or over) live in this household?
# 	- How many children under the age of 18 live in this household?
# 	- Which of the following best describes your current primary residence? I/We live in...
# 	- Employed part time: Q2149 What is your employment status? Please select all that apply.
# 	- Self-employed: Q2149 What is your employment status? Please select all that apply.
# 	- Not employed, but looking for work: Q2149 What is your employment status? Please select all that apply.
# 	- Not employed and not looking for work: Q2149 What is your employment status? Please select all that apply.
# 	- Retired: Q2149 What is your employment status? Please select all that apply.
# 	- Not employed, unable to work due to a disability or illness: Q2149 What is your employment status? Please select all that apply.
# 	- Student: Q2149 What is your employment status? Please select all that apply.
# 	- Homemaker: Q2149 What is your employment status? Please select all that apply.
# 	- Race/Ethnicity E
# 	- Unnamed: 180
# 	- Insomnia Nights Per Week B
# 	- Country of Residence
# 	- 2020 President Trump approval
#
# ========================================
#
# zenodo_v2 columns:
# 	- Dream Report ID
# 	- Title
# 	- Dream Text
# 	- Participant ID
# 	- Gender
# 	- Age
# 	- Word Count
# 	- Dream Date
# 	- Survey Name
# 	- Survey ID
# 	- Question
# 	- Categories
